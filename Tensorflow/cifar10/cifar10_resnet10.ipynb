# %% [markdown]
# <a href="https://colab.research.google.com/github/td-iceman/Tarandeep-Projects/blob/main/Tensorflow/cifar10/cifar10_resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ResNet model for CIFAR-10 image recognition
#
# <br />
# This code shows an implementation of the residual network block to create a 10 resnet block CNN for performing CIFAR-10 image recognition task. This notebook was run using Google collab.
# <br />

# %%
#@title Default title text
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10

tf.version.VERSION
# Out:
# '2.8.2'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print(X_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3)

# %%
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig, axes = plt.subplots(ncols=7, nrows=3, figsize=(17, 8))
index = 0
for i in range(3):
    for j in range(7):
        axes[i,j].set_title(labels[y_train[index][0]])
        axes[i,j].imshow(X_train[index])
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        index += 1
plt.show()

# %%
## -- resnet block function -- 
## -- weights->BN->relu->weights->BN-->Add->relu --

def resnet_block(in_layer, kernel):
    filters = in_layer.shape[3]
    a = tf.keras.layers.Conv2D(
        filters=filters,
        kernel_size=kernel,
        activation = None,
        padding='same'
    )(in_layer)
    b = tf.keras.layers.BatchNormalization()(a)
    c = tf.keras.layers.Activation('relu')(b)

    d = tf.keras.layers.Conv2D(
        filters=filters,
        kernel_size=kernel,
        activation = None,
        padding='same'
    )(c)
    e = tf.keras.layers.BatchNormalization()(d)
    f = tf.keras.layers.Add()([e, in_layer])
    g = tf.keras.layers.Activation('relu')(f)
    return g

# %%
in_put = tf.keras.Input(shape=(32,32,3), name='input_layer')

## -- RES-SUPERBLOCK 1 --
conv1 = tf.keras.layers.Conv2D( name='plain_conv1',
        filters=32,
        kernel_size=3,
        activation = 'relu',
        padding='same'
)(in_put)
res1 = resnet_block(conv1, kernel=3)
res2 = resnet_block(res1, kernel=3)
res3 = resnet_block(res2, kernel=3)
# -- max pool 1 --
pool1 = tf.keras.layers.MaxPool2D( name='pool1',
    pool_size=(2, 2),
)(res3)


## -- RES-SUPERBLOCK 2 --
conv3 = tf.keras.layers.Conv2D( name='plain_conv3',
        filters=64,
        kernel_size=3,
        activation = 'relu',
        padding='same'
)(pool1)
res4 = resnet_block(conv3, kernel=3)
res5 = resnet_block(res4, kernel=3)
res6 = resnet_block(res5, kernel=3)
# -- max pool 2 --
pool2 = tf.keras.layers.MaxPool2D( name='pool2',
    pool_size=(2, 2),
)(res6)


## -- RES-SUPERBLOCK 3 --
conv5 = tf.keras.layers.Conv2D( name='plain_conv5',
        filters=128,
        kernel_size=3,
        activation = 'relu',
        padding='same'
)(pool2)
res7 = resnet_block(conv5, kernel=3)
res8 = resnet_block(res7, kernel=3)
res9 = resnet_block(res8, kernel=3)
res10 = resnet_block(res9, kernel=3)
pool3 = tf.keras.layers.MaxPool2D( name='pool3',
    pool_size=(2, 2),
)(res9)


flat1 = tf.keras.layers.Flatten()(pool3)
dense1 = tf.keras.layers.Dense(120, activation='relu', name='dense1')(flat1)
output = tf.keras.layers.Dense(10, activation='softmax')(dense1)

model_res = tf.keras.Model(in_put, output)

# %%
model_res.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 32, 32, 3)]  0           []
#
#  plain_conv1 (Conv2D)           (None, 32, 32, 32)   896         ['input_layer[0][0]']
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   9248        ['plain_conv1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 32, 32, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 32)   9248        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 32, 32, 32)   0           ['batch_normalization_1[0][0]',
#                                                                   'plain_conv1[0][0]']
#
#  activation_1 (Activation)      (None, 32, 32, 32)   0           ['add[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 32)   9248        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 32)   9248        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 32, 32, 32)   0           ['batch_normalization_3[0][0]',
#                                                                   'activation_1[0][0]']
#
#  activation_3 (Activation)      (None, 32, 32, 32)   0           ['add_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 32)   9248        ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 32)   9248        ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 32, 32, 32)   0           ['batch_normalization_5[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_5 (Activation)      (None, 32, 32, 32)   0           ['add_2[0][0]']
#
#  pool1 (MaxPooling2D)           (None, 16, 16, 32)   0           ['activation_5[0][0]']
#
#  plain_conv3 (Conv2D)           (None, 16, 16, 64)   18496       ['pool1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 64)   36928       ['plain_conv3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 16, 16, 64)   0           ['batch_normalization_7[0][0]',
#                                                                   'plain_conv3[0][0]']
#
#  activation_7 (Activation)      (None, 16, 16, 64)   0           ['add_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 64)   36928       ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 16, 16, 64)   0           ['batch_normalization_9[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_9 (Activation)      (None, 16, 16, 64)   0           ['add_4[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 64)  256         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 64)   36928       ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 64)  256         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 16, 16, 64)   0           ['batch_normalization_11[0][0]',
#                                                                   'activation_9[0][0]']
#
#  activation_11 (Activation)     (None, 16, 16, 64)   0           ['add_5[0][0]']
#
#  pool2 (MaxPooling2D)           (None, 8, 8, 64)     0           ['activation_11[0][0]']
#
#  plain_conv5 (Conv2D)           (None, 8, 8, 128)    73856       ['pool2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 128)    147584      ['plain_conv5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 128)   512         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 8, 8, 128)    0           ['batch_normalization_13[0][0]',
#                                                                   'plain_conv5[0][0]']
#
#  activation_13 (Activation)     (None, 8, 8, 128)    0           ['add_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 8, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 8, 8, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 8, 8, 128)    0           ['batch_normalization_15[0][0]',
#                                                                   'activation_13[0][0]']
#
#  activation_15 (Activation)     (None, 8, 8, 128)    0           ['add_7[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 8, 8, 128)   512         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 8, 8, 128)    0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 8, 8, 128)    147584      ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 8, 128)   512         ['conv2d_17[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 8, 8, 128)    0           ['batch_normalization_17[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_17 (Activation)     (None, 8, 8, 128)    0           ['add_8[0][0]']
#
#  pool3 (MaxPooling2D)           (None, 4, 4, 128)    0           ['activation_17[0][0]']
#
#  flatten (Flatten)              (None, 2048)         0           ['pool3[0][0]']
#
#  dense1 (Dense)                 (None, 120)          245880      ['flatten[0][0]']
#
#  dense (Dense)                  (None, 10)           1210        ['dense1[0][0]']
#
# ==================================================================================================
# Total params: 1,508,274
# Trainable params: 1,505,586
# Non-trainable params: 2,688
# __________________________________________________________________________________________________

# %%
## -- creating dataset using TF Dataset API --

BATCH_SIZE = 100
dataset = tf.data.Dataset.from_tensor_slices(((X_train/255.).reshape(-1,32,32,3), 
                                              to_categorical(y_train.reshape(-1,1))))
dataset = dataset.shuffle(len(X_train)).batch(BATCH_SIZE)

testset = tf.data.Dataset.from_tensor_slices(((X_test/255.).reshape(-1,32,32,3), 
                                              to_categorical(y_test.reshape(-1,1))))
testset = testset.shuffle(len(X_test)).batch(BATCH_SIZE)

# -- plotting two examples from the shuffled dataset
fig, axes = plt.subplots(ncols=2, nrows=1)
for i,m in enumerate(dataset.take(2)):
    axes[i].imshow(m[0][0])
plt.show()

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=150,
    decay_rate=0.95)

model_res.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule), loss='CategoricalCrossentropy', metrics=['accuracy'])

history = model_res.fit(dataset, epochs=20, validation_data=testset)
# Out:
# Epoch 1/20
# 500/500 [==============================] - 37s 47ms/step - loss: 1.7147 - accuracy: 0.3968 - val_loss: 2.7717 - val_accuracy: 0.2715
# Epoch 2/20
# 500/500 [==============================] - 23s 46ms/step - loss: 0.9912 - accuracy: 0.6453 - val_loss: 0.9589 - val_accuracy: 0.6593
# Epoch 3/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.7529 - accuracy: 0.7322 - val_loss: 1.2890 - val_accuracy: 0.5932
# Epoch 4/20
# 500/500 [==============================] - 23s 47ms/step - loss: 0.6195 - accuracy: 0.7814 - val_loss: 0.7127 - val_accuracy: 0.7553
# Epoch 5/20
# 500/500 [==============================] - 23s 47ms/step - loss: 0.5181 - accuracy: 0.8167 - val_loss: 0.8722 - val_accuracy: 0.7226
# Epoch 6/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.4269 - accuracy: 0.8491 - val_loss: 0.7979 - val_accuracy: 0.7470
# Epoch 7/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.3462 - accuracy: 0.8775 - val_loss: 0.5937 - val_accuracy: 0.8006
# Epoch 8/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.2675 - accuracy: 0.9067 - val_loss: 0.6889 - val_accuracy: 0.7909
# Epoch 9/20
# 500/500 [==============================] - 23s 47ms/step - loss: 0.1928 - accuracy: 0.9336 - val_loss: 0.7530 - val_accuracy: 0.7901
# Epoch 10/20
# 500/500 [==============================] - 24s 48ms/step - loss: 0.1318 - accuracy: 0.9564 - val_loss: 0.6431 - val_accuracy: 0.8131
# Epoch 11/20
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0832 - accuracy: 0.9754 - val_loss: 0.6388 - val_accuracy: 0.8236
# Epoch 12/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0494 - accuracy: 0.9878 - val_loss: 0.6713 - val_accuracy: 0.8235
# Epoch 13/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0282 - accuracy: 0.9953 - val_loss: 0.7542 - val_accuracy: 0.8210
# Epoch 14/20
# 500/500 [==============================] - 24s 48ms/step - loss: 0.0163 - accuracy: 0.9983 - val_loss: 0.7015 - val_accuracy: 0.8379
# Epoch 15/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0095 - accuracy: 0.9996 - val_loss: 0.7470 - val_accuracy: 0.8351
# Epoch 16/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0063 - accuracy: 0.9998 - val_loss: 0.7506 - val_accuracy: 0.8372
# Epoch 17/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0042 - accuracy: 0.9999 - val_loss: 0.7554 - val_accuracy: 0.8361
# Epoch 18/20
# 500/500 [==============================] - 23s 46ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7844 - val_accuracy: 0.8369
# Epoch 19/20
# 500/500 [==============================] - 23s 47ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7919 - val_accuracy: 0.8372
# Epoch 20/20
# 500/500 [==============================] - 24s 47ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8159 - val_accuracy: 0.8383

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %%
[loss, acc] = model_res.evaluate(testset)
print(f'Accuracy on test data: {round(acc*100,1)} %')
# Out:
# 100/100 [==============================] - 2s 15ms/step - loss: 0.8159 - accuracy: 0.8383
# Accuracy on test data: 83.8 %

# %% [markdown]
# <br />
# The resnet model with 10 residual network blocks performs with an accuracy of about 84% on the cifar10 dataset.
#
# <br />
